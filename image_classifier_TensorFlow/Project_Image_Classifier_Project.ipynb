# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# TODO: Make all necessary imports.
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub

import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

import json
import time

# %%
print('Using:')
print('\t\u2022 TensorFlow version:', tf.__version__)
print('\t\u2022 tf.keras version:', tf.keras.__version__)
print('\t\u2022 Running on GPU' if tf.test.is_gpu_available() else '\t\u2022 GPU device not found. Running on CPU')
# Out:
# Using:
# 	• TensorFlow version: 2.2.0
# 	• tf.keras version: 2.3.0-tf
# 	• GPU device not found. Running on CPU

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# TODO: Load the dataset with TensorFlow Datasets.
# Load training data
# TODO: Create a training set, a validation set and a test set.
(training_set, test_set, validation_set), metadata = tfds.load('oxford_flowers102', 
                                                                split = ['train','test','validation'],
                                                                as_supervised = True,
                                                                with_info = True)

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.
for split_ in ['train','test','validation']:
    num_training_examples = metadata.splits[split_].num_examples
    print('There are {:,} images in the {} set'.format(num_training_examples,split_))

# TODO: Get the number of classes in the dataset from the dataset info.
num_classes = metadata.features['label'].num_classes
print('\nThere are {:,} classes in dataset'.format(num_classes))
# Out:
# There are 1,020 images in the train set
# There are 6,149 images in the test set
# There are 1,020 images in the validation set
#
# There are 102 classes in dataset

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
n = 1
for image, label in training_set.take(3):
    image_show = image.numpy().squeeze()
    label = label.numpy()
    print('{} image: label is {}, shape is {}'.format(n, label, image.shape))
    n += 1
# Out:
# 1 image: label is 72, shape is (500, 667, 3)
# 2 image: label is 84, shape is (500, 666, 3)
# 3 image: label is 70, shape is (670, 500, 3)

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 
# Plot the image
plt.imshow(image_show)
plt.show()
print('The label of this image is:', label)
# Out:
# The label of this image is: 70

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
with open('label_map.json', 'r') as f:
    class_names = json.load(f)
    
# Fix the flower number. Need to align starting points. 
class_names_ = pd.DataFrame.from_dict(class_names,orient='index').reset_index()
class_names_['index'] = class_names_['index'].astype(int)-1
class_names_ = class_names_.set_index('index')
class_names = pd.DataFrame.to_dict(class_names_)[0]

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 
plt.imshow(image_show)
plt.show()
print('The label of this image is:', class_names[label])
# Out:
# The label of this image is: gazania

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.
batch_size = 32
image_size = 224
shuffle_size = metadata.splits['train'].num_examples//4

def format_image(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, (image_size, image_size))
    image /= 255
    return image, label


training_batches = training_set.shuffle(shuffle_size).map(format_image).batch(batch_size).prefetch(1)
validation_batches = validation_set.map(format_image).batch(batch_size).prefetch(1)
testing_batches = test_set.map(format_image).batch(batch_size).prefetch(1)

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network.
image_shape = (image_size, image_size, 3)

URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(URL, input_shape=image_shape)
feature_extractor.trainable = False

model = tf.keras.Sequential([feature_extractor,
                            tf.keras.layers.Dense(num_classes, activation = 'softmax')])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

EPOCHS = 10

history = model.fit(training_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 49s 2s/step - loss: 4.2810 - accuracy: 0.1294 - val_loss: 3.1076 - val_accuracy: 0.3853
# Epoch 2/10
# 32/32 [==============================] - 48s 1s/step - loss: 2.0700 - accuracy: 0.7049 - val_loss: 2.0047 - val_accuracy: 0.6471
# Epoch 3/10
# 32/32 [==============================] - 40s 1s/step - loss: 1.0897 - accuracy: 0.9010 - val_loss: 1.5250 - val_accuracy: 0.7324
# Epoch 4/10
# 32/32 [==============================] - 42s 1s/step - loss: 0.6561 - accuracy: 0.9588 - val_loss: 1.2854 - val_accuracy: 0.7696
# Epoch 5/10
# 32/32 [==============================] - 39s 1s/step - loss: 0.4386 - accuracy: 0.9824 - val_loss: 1.1512 - val_accuracy: 0.7873
# Epoch 6/10
# 32/32 [==============================] - 39s 1s/step - loss: 0.3131 - accuracy: 0.9931 - val_loss: 1.0616 - val_accuracy: 0.7951
# Epoch 7/10
# 32/32 [==============================] - 42s 1s/step - loss: 0.2327 - accuracy: 0.9980 - val_loss: 0.9991 - val_accuracy: 0.8029
# Epoch 8/10
# 32/32 [==============================] - 40s 1s/step - loss: 0.1806 - accuracy: 0.9990 - val_loss: 0.9514 - val_accuracy: 0.8127
# Epoch 9/10
# 32/32 [==============================] - 37s 1s/step - loss: 0.1443 - accuracy: 1.0000 - val_loss: 0.9176 - val_accuracy: 0.8176
# Epoch 10/10
# 32/32 [==============================] - 37s 1s/step - loss: 0.1184 - accuracy: 1.0000 - val_loss: 0.8867 - val_accuracy: 0.8206

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(EPOCHS)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.
tfds.disable_progress_bar()

loss_ = []
accuracy_ = []
for image_batch, label_batch in testing_batches:
    loss, accuracy = model.evaluate(image_batch, label_batch)
    loss_.append(loss)
    accuracy_.append(accuracy)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0564 - accuracy: 0.8125
# 1/1 [==============================] - 0s 854us/step - loss: 0.9693 - accuracy: 0.7812
# 1/1 [==============================] - 0s 870us/step - loss: 0.8780 - accuracy: 0.8438
# 1/1 [==============================] - 0s 907us/step - loss: 1.0858 - accuracy: 0.7188
# 1/1 [==============================] - 0s 899us/step - loss: 1.2526 - accuracy: 0.6875
# 1/1 [==============================] - 0s 865us/step - loss: 1.2811 - accuracy: 0.6875
# 1/1 [==============================] - 0s 865us/step - loss: 1.0344 - accuracy: 0.7500
# 1/1 [==============================] - 0s 901us/step - loss: 1.0361 - accuracy: 0.8125
# 1/1 [==============================] - 0s 915us/step - loss: 0.9818 - accuracy: 0.7188
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1466 - accuracy: 0.7500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1605 - accuracy: 0.7188
# 1/1 [==============================] - 0s 872us/step - loss: 1.3174 - accuracy: 0.6250
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4496 - accuracy: 0.5938
# 1/1 [==============================] - 0s 875us/step - loss: 1.0429 - accuracy: 0.6875
# 1/1 [==============================] - 0s 877us/step - loss: 0.8650 - accuracy: 0.7812
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9512 - accuracy: 0.8750
# 1/1 [==============================] - 0s 835us/step - loss: 1.1147 - accuracy: 0.7188
# 1/1 [==============================] - 0s 883us/step - loss: 0.7931 - accuracy: 0.8438
# 1/1 [==============================] - 0s 874us/step - loss: 0.8500 - accuracy: 0.8125
# 1/1 [==============================] - 0s 872us/step - loss: 1.0603 - accuracy: 0.7500
# 1/1 [==============================] - 0s 865us/step - loss: 1.1552 - accuracy: 0.7188
# 1/1 [==============================] - 0s 882us/step - loss: 1.3150 - accuracy: 0.6562
# 1/1 [==============================] - 0s 950us/step - loss: 0.8457 - accuracy: 0.7812
# 1/1 [==============================] - 0s 870us/step - loss: 1.1350 - accuracy: 0.7500
# 1/1 [==============================] - 0s 866us/step - loss: 1.3276 - accuracy: 0.7500
# 1/1 [==============================] - 0s 885us/step - loss: 0.7901 - accuracy: 0.7812
# 1/1 [==============================] - 0s 892us/step - loss: 1.4653 - accuracy: 0.7188
# 1/1 [==============================] - 0s 821us/step - loss: 1.0463 - accuracy: 0.7188
# 1/1 [==============================] - 0s 897us/step - loss: 0.9940 - accuracy: 0.7812
# 1/1 [==============================] - 0s 893us/step - loss: 1.0833 - accuracy: 0.7500
# 1/1 [==============================] - 0s 861us/step - loss: 0.8825 - accuracy: 0.7500
# 1/1 [==============================] - 0s 876us/step - loss: 0.7909 - accuracy: 0.8438
# 1/1 [==============================] - 0s 867us/step - loss: 0.7300 - accuracy: 0.8750
# 1/1 [==============================] - 0s 871us/step - loss: 0.7014 - accuracy: 0.8438
# 1/1 [==============================] - 0s 803us/step - loss: 1.0084 - accuracy: 0.7500
# 1/1 [==============================] - 0s 852us/step - loss: 0.9501 - accuracy: 0.7188
# 1/1 [==============================] - 0s 887us/step - loss: 1.4710 - accuracy: 0.7188
# 1/1 [==============================] - 0s 863us/step - loss: 0.8310 - accuracy: 0.7812
# 1/1 [==============================] - 0s 852us/step - loss: 0.9630 - accuracy: 0.8125
# 1/1 [==============================] - 0s 827us/step - loss: 1.4320 - accuracy: 0.5938
# 1/1 [==============================] - 0s 881us/step - loss: 1.0584 - accuracy: 0.7188
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8209 - accuracy: 0.8125
# 1/1 [==============================] - 0s 799us/step - loss: 0.9597 - accuracy: 0.7812
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5611 - accuracy: 0.8438
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8351 - accuracy: 0.8438
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7830 - accuracy: 0.7500
# 1/1 [==============================] - 0s 880us/step - loss: 1.3947 - accuracy: 0.7812
# 1/1 [==============================] - 0s 862us/step - loss: 1.0589 - accuracy: 0.8125
# 1/1 [==============================] - 0s 977us/step - loss: 1.0049 - accuracy: 0.7500
# 1/1 [==============================] - 0s 897us/step - loss: 1.2543 - accuracy: 0.7500
# 1/1 [==============================] - 0s 866us/step - loss: 0.7970 - accuracy: 0.8750
# 1/1 [==============================] - 0s 858us/step - loss: 1.1311 - accuracy: 0.7500
# 1/1 [==============================] - 0s 875us/step - loss: 1.2450 - accuracy: 0.6875
# 1/1 [==============================] - 0s 852us/step - loss: 1.3155 - accuracy: 0.7500
# 1/1 [==============================] - 0s 865us/step - loss: 0.7344 - accuracy: 0.8438
# 1/1 [==============================] - 0s 885us/step - loss: 1.1018 - accuracy: 0.7500
# 1/1 [==============================] - 0s 848us/step - loss: 0.9110 - accuracy: 0.8438
# 1/1 [==============================] - 0s 873us/step - loss: 0.9259 - accuracy: 0.8125
# 1/1 [==============================] - 0s 858us/step - loss: 0.8138 - accuracy: 0.8438
# 1/1 [==============================] - 0s 821us/step - loss: 0.8407 - accuracy: 0.7500
# 1/1 [==============================] - 0s 950us/step - loss: 1.1926 - accuracy: 0.6875
# 1/1 [==============================] - 0s 873us/step - loss: 0.7738 - accuracy: 0.8750
# 1/1 [==============================] - 0s 855us/step - loss: 0.8572 - accuracy: 0.8438
# 1/1 [==============================] - 0s 934us/step - loss: 0.9541 - accuracy: 0.8125
# 1/1 [==============================] - 0s 872us/step - loss: 1.1439 - accuracy: 0.7188
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8854 - accuracy: 0.7812
# 1/1 [==============================] - 0s 899us/step - loss: 0.7903 - accuracy: 0.8750
# 1/1 [==============================] - 0s 897us/step - loss: 1.1014 - accuracy: 0.7812
# 1/1 [==============================] - 0s 926us/step - loss: 1.2106 - accuracy: 0.7812
# 1/1 [==============================] - 0s 941us/step - loss: 0.8189 - accuracy: 0.8438
# 1/1 [==============================] - 0s 940us/step - loss: 1.0385 - accuracy: 0.7812
# 1/1 [==============================] - 0s 945us/step - loss: 0.7515 - accuracy: 0.8125
# 1/1 [==============================] - 0s 894us/step - loss: 0.8190 - accuracy: 0.8125
# 1/1 [==============================] - 0s 807us/step - loss: 1.6713 - accuracy: 0.5625
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9161 - accuracy: 0.7812
# 1/1 [==============================] - 0s 967us/step - loss: 0.6954 - accuracy: 0.8125
# 1/1 [==============================] - 0s 862us/step - loss: 1.1418 - accuracy: 0.7812
# 1/1 [==============================] - 0s 938us/step - loss: 1.3077 - accuracy: 0.6562
# 1/1 [==============================] - 0s 868us/step - loss: 0.6077 - accuracy: 0.9375
# 1/1 [==============================] - 0s 913us/step - loss: 0.9391 - accuracy: 0.7500
# 1/1 [==============================] - 0s 942us/step - loss: 0.8285 - accuracy: 0.7812
# 1/1 [==============================] - 0s 861us/step - loss: 1.1285 - accuracy: 0.7812
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4648 - accuracy: 0.6562
# 1/1 [==============================] - 0s 961us/step - loss: 1.1923 - accuracy: 0.7188
# 1/1 [==============================] - 0s 937us/step - loss: 1.1368 - accuracy: 0.7500
# 1/1 [==============================] - 0s 992us/step - loss: 0.8872 - accuracy: 0.8125
# 1/1 [==============================] - 0s 775us/step - loss: 1.0623 - accuracy: 0.7500
# 1/1 [==============================] - 0s 982us/step - loss: 0.9442 - accuracy: 0.6875
# 1/1 [==============================] - 0s 942us/step - loss: 0.7583 - accuracy: 0.8750
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7870 - accuracy: 0.8438
# 1/1 [==============================] - 0s 819us/step - loss: 1.2226 - accuracy: 0.7812
# 1/1 [==============================] - 0s 906us/step - loss: 1.3148 - accuracy: 0.6875
# 1/1 [==============================] - 0s 854us/step - loss: 0.9825 - accuracy: 0.8750
# 1/1 [==============================] - 0s 880us/step - loss: 0.8674 - accuracy: 0.8438
# 1/1 [==============================] - 0s 857us/step - loss: 0.8892 - accuracy: 0.8750
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7360 - accuracy: 0.8750
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7282 - accuracy: 0.8125
# 1/1 [==============================] - 0s 883us/step - loss: 1.0969 - accuracy: 0.6875
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1928 - accuracy: 0.6562
# 1/1 [==============================] - 0s 849us/step - loss: 0.7705 - accuracy: 0.8125
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9943 - accuracy: 0.7812
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8307 - accuracy: 0.7812
# 1/1 [==============================] - 0s 903us/step - loss: 0.8478 - accuracy: 0.7812
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3314 - accuracy: 0.6562
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8935 - accuracy: 0.8125
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8305 - accuracy: 0.8438
# 1/1 [==============================] - 0s 903us/step - loss: 1.0863 - accuracy: 0.7500
# 1/1 [==============================] - 0s 920us/step - loss: 1.2951 - accuracy: 0.7188
# 1/1 [==============================] - 0s 998us/step - loss: 1.4139 - accuracy: 0.7500
# 1/1 [==============================] - 0s 846us/step - loss: 0.7661 - accuracy: 0.8750
# 1/1 [==============================] - 0s 787us/step - loss: 1.2095 - accuracy: 0.7188
# 1/1 [==============================] - 0s 906us/step - loss: 0.8718 - accuracy: 0.8125
# 1/1 [==============================] - 0s 898us/step - loss: 0.8844 - accuracy: 0.8438
# 1/1 [==============================] - 0s 876us/step - loss: 0.8321 - accuracy: 0.7500
# 1/1 [==============================] - 0s 832us/step - loss: 1.0841 - accuracy: 0.7812
# 1/1 [==============================] - 0s 852us/step - loss: 1.3131 - accuracy: 0.6562
# 1/1 [==============================] - 0s 782us/step - loss: 0.8147 - accuracy: 0.9062
# 1/1 [==============================] - 0s 955us/step - loss: 0.8493 - accuracy: 0.7812
# 1/1 [==============================] - 0s 856us/step - loss: 1.1623 - accuracy: 0.7812
# 1/1 [==============================] - 0s 867us/step - loss: 0.5828 - accuracy: 0.8750
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9209 - accuracy: 0.8125
# 1/1 [==============================] - 0s 876us/step - loss: 0.7950 - accuracy: 0.8750
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2262 - accuracy: 0.7500
# 1/1 [==============================] - 0s 812us/step - loss: 1.1389 - accuracy: 0.8125
# 1/1 [==============================] - 0s 894us/step - loss: 0.9334 - accuracy: 0.8438
# 1/1 [==============================] - 0s 923us/step - loss: 1.0223 - accuracy: 0.7812
# 1/1 [==============================] - 0s 900us/step - loss: 0.8096 - accuracy: 0.8438
# 1/1 [==============================] - 0s 895us/step - loss: 0.9858 - accuracy: 0.8125
# 1/1 [==============================] - 0s 862us/step - loss: 1.2562 - accuracy: 0.6562
# 1/1 [==============================] - 0s 862us/step - loss: 1.0132 - accuracy: 0.8125
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7500 - accuracy: 0.8125
# 1/1 [==============================] - 0s 928us/step - loss: 1.0604 - accuracy: 0.7500
# 1/1 [==============================] - 0s 864us/step - loss: 1.0559 - accuracy: 0.7188
# 1/1 [==============================] - 0s 831us/step - loss: 1.3819 - accuracy: 0.7500
# 1/1 [==============================] - 0s 857us/step - loss: 1.1676 - accuracy: 0.7500
# 1/1 [==============================] - 0s 843us/step - loss: 0.8314 - accuracy: 0.9062
# 1/1 [==============================] - 0s 919us/step - loss: 1.0807 - accuracy: 0.7500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7531 - accuracy: 0.8750
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8548 - accuracy: 0.7812
# 1/1 [==============================] - 0s 895us/step - loss: 1.1597 - accuracy: 0.5938
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8887 - accuracy: 0.7500
# 1/1 [==============================] - 0s 985us/step - loss: 0.5266 - accuracy: 0.9062
# 1/1 [==============================] - 0s 877us/step - loss: 1.0936 - accuracy: 0.7500
# 1/1 [==============================] - 0s 930us/step - loss: 0.9562 - accuracy: 0.7188
# 1/1 [==============================] - 0s 887us/step - loss: 1.6055 - accuracy: 0.6875
# 1/1 [==============================] - 0s 915us/step - loss: 0.7825 - accuracy: 0.8750
# 1/1 [==============================] - 0s 932us/step - loss: 0.9631 - accuracy: 0.7500
# 1/1 [==============================] - 0s 812us/step - loss: 1.1288 - accuracy: 0.8438
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8921 - accuracy: 0.7500
# 1/1 [==============================] - 0s 933us/step - loss: 0.7032 - accuracy: 0.8750
# 1/1 [==============================] - 0s 908us/step - loss: 1.0766 - accuracy: 0.8125
# 1/1 [==============================] - 0s 868us/step - loss: 0.8677 - accuracy: 0.7500
# 1/1 [==============================] - 0s 873us/step - loss: 1.3033 - accuracy: 0.7188
# 1/1 [==============================] - 0s 889us/step - loss: 1.0993 - accuracy: 0.8438
# 1/1 [==============================] - 0s 932us/step - loss: 1.2001 - accuracy: 0.6875
# 1/1 [==============================] - 0s 905us/step - loss: 0.8285 - accuracy: 0.8125
# 1/1 [==============================] - 0s 888us/step - loss: 0.9667 - accuracy: 0.7812
# 1/1 [==============================] - 0s 886us/step - loss: 0.8072 - accuracy: 0.8750
# 1/1 [==============================] - 0s 882us/step - loss: 1.1338 - accuracy: 0.7812
# 1/1 [==============================] - 0s 936us/step - loss: 1.3079 - accuracy: 0.6562
# 1/1 [==============================] - 0s 854us/step - loss: 0.9624 - accuracy: 0.7812
# 1/1 [==============================] - 0s 896us/step - loss: 1.0742 - accuracy: 0.7812
# 1/1 [==============================] - 0s 864us/step - loss: 0.9093 - accuracy: 0.8438
# 1/1 [==============================] - 0s 905us/step - loss: 0.7871 - accuracy: 0.8125
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4091 - accuracy: 0.7188
# 1/1 [==============================] - 0s 887us/step - loss: 1.0928 - accuracy: 0.7812
# 1/1 [==============================] - 0s 919us/step - loss: 0.9451 - accuracy: 0.7500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4007 - accuracy: 0.7188
# 1/1 [==============================] - 0s 951us/step - loss: 1.0642 - accuracy: 0.7188
# 1/1 [==============================] - 0s 855us/step - loss: 0.7399 - accuracy: 0.8438
# 1/1 [==============================] - 0s 862us/step - loss: 1.5117 - accuracy: 0.6875
# 1/1 [==============================] - 0s 883us/step - loss: 1.6286 - accuracy: 0.6562
# 1/1 [==============================] - 0s 966us/step - loss: 1.1981 - accuracy: 0.7500
# 1/1 [==============================] - 0s 892us/step - loss: 0.9340 - accuracy: 0.7812
# 1/1 [==============================] - 0s 872us/step - loss: 0.9602 - accuracy: 0.7500
# 1/1 [==============================] - 0s 851us/step - loss: 0.7752 - accuracy: 0.7812
# 1/1 [==============================] - 0s 895us/step - loss: 1.2855 - accuracy: 0.7188
# 1/1 [==============================] - 0s 900us/step - loss: 0.7379 - accuracy: 0.8125
# 1/1 [==============================] - 0s 885us/step - loss: 0.9264 - accuracy: 0.9062
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0788 - accuracy: 0.6562
# 1/1 [==============================] - 0s 845us/step - loss: 1.3852 - accuracy: 0.6562
# 1/1 [==============================] - 0s 911us/step - loss: 1.2763 - accuracy: 0.7500
# 1/1 [==============================] - 0s 920us/step - loss: 0.8744 - accuracy: 0.8125
# 1/1 [==============================] - 0s 941us/step - loss: 0.7653 - accuracy: 0.8125
# 1/1 [==============================] - 0s 932us/step - loss: 0.7911 - accuracy: 0.8438
# 1/1 [==============================] - 0s 885us/step - loss: 1.1321 - accuracy: 0.8125
# 1/1 [==============================] - 0s 891us/step - loss: 0.4083 - accuracy: 0.9375
# 1/1 [==============================] - 0s 884us/step - loss: 0.8333 - accuracy: 0.8438
# 1/1 [==============================] - 0s 908us/step - loss: 1.3885 - accuracy: 0.6875
# 1/1 [==============================] - 0s 923us/step - loss: 0.7343 - accuracy: 0.8750
# 1/1 [==============================] - 0s 851us/step - loss: 0.9159 - accuracy: 0.8125
# 1/1 [==============================] - 0s 930us/step - loss: 0.9896 - accuracy: 0.8125
# 1/1 [==============================] - 0s 952us/step - loss: 0.2985 - accuracy: 1.0000

# %%
print('Loss on the entire test set: {:,.3f}'.format(np.average(loss_)))
print('Accuracy on the entire test set: {:.3%}'.format(np.average(accuracy_)))
# Out:
# Loss on the entire test set: 1.010
# Accuracy on the entire test set: 77.688%

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.
model.save('model.h5')

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model
loaded_model = tf.keras.models.load_model('model.h5',custom_objects={'KerasLayer':hub.KerasLayer})

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function
def process_image(image):
    
    image_size = 224
    image = tf.image.resize(image, (image_size, image_size))
    image /= 255
    
    return image.numpy()

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function

def predict(image_path, model, top_k):

    im = Image.open(image_path)
    test_image = np.asarray(im)

    processed_test_image = process_image(test_image)

    reshape_test_image = np.expand_dims(processed_test_image, axis = 0)
    
    ps = model.predict(reshape_test_image)
    
    classes = np.argsort(ps[0])[::-1][:top_k]
    probs = ps[0][classes]
    
    return probs, classes

# %%
probs, classes = predict('./test_images/hard-leaved_pocket_orchid.jpg', model, 5)

print('Pobabilities are: \n{}'.format(probs))
print('\nClasses are: \n{}'.format(classes))
# Out:
# Pobabilities are:
# [9.9504566e-01 1.2840977e-03 6.9576793e-04 4.4405676e-04 2.9880402e-04]
#
# Classes are:
# [ 1 79  5 67  6]

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes

for flower in ['cautleya_spicata.jpg',
               'hard-leaved_pocket_orchid.jpg',
               'orange_dahlia.jpg',
               'wild_pansy.jpg']:
    path = './test_images/{}'.format(flower)
    
    im = Image.open(path)
    test_image = np.asarray(im)
    
    probs, classes = predict(path, model, 5)
    
    names = []
    for i in classes:
        names.append(class_names[i])
    
    fig, (ax1, ax2) = plt.subplots(figsize=(10,5), ncols=2)
    ax1.imshow(test_image, cmap = plt.cm.binary)
    ax1.axis('off')
    ax2.barh(names, probs)
    #ax2.set_aspect(0.1)
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)
    plt.tight_layout()
